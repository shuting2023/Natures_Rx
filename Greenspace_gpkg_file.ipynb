# %% [markdown]
# # Choropleth Mapy by using GPKG File
#
# This notebook is aming to explore the gpkg file and use its information to create choropleth map.
#
# Obejectives:
# - Exploring the GPKG file from GreenSpace datasets
# - Create choropleth map by using converted gpkg file and merged datasets
#
#
# Conclusion:
# - The file can be read by geopandas.
# - The ...V1_2.gpkg contains MULTIPOLYGON data, can be used as area boundary for the choropleth map.
#
# *Note: ...V1_2.gpkg file is very large, so it may take few minutes to load.*

# %%
import GeoBound_ChoroplethMap as gcm
import geopandas as gpd
from shapely.geometry import Point
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Explore GPKG

# %%
gpkg_path = 'GreenspaceDownload/GHS_STAT_UCDB2015MT_GLOBE_R2019A_V1_2.gpkg'

def load_gpkg(gpkg_path):
    print('Loading large file, will take 1-2 minutes...')
    gdf = gpd.read_file(gpkg_path)
    return gdf

# %%
gdf = load_gpkg(gpkg_path)
gdf.head()
# Out:
# Loading large file, will take 1-2 minutes...
#    ID_HDC_G0  QA2_1V   AREA  BBX_LATMN   BBX_LONMN  BBX_LATMX   BBX_LONMX  \
# 0        1.0     1.0  185.0  21.247683 -158.043016  21.422193 -157.730529
# 1        2.0     2.0   42.0 -17.641184 -149.628088 -17.517631 -149.508018
# 2        3.0     1.0   55.0  34.858517 -120.475511  34.989334 -120.389183
# 3        4.0     1.0   48.0  36.582997 -121.952215  36.635743 -121.811816
# 4        5.0     1.0   60.0  34.388220 -119.853855  34.457831 -119.658413
#
#    GCPNT_LAT   GCPNT_LON         CTR_MN_NM  ...      EX_SS_P00      EX_SS_P15  \
# 0  21.340678 -157.893497     United States  ...  397443.031445  444041.529529
# 1 -17.534103 -149.568053  French Polynesia  ...       0.000000       0.000000
# 2  34.923123 -120.434372     United States  ...       0.000000       0.000000
# 3  36.607720 -121.882378     United States  ...       0.000000       0.000000
# 4  34.427664 -119.743693     United States  ...       0.000000       0.000000
#
#    EX_EQ19PGA EX_EQ19MMI  EX_EQ19_Q EX_HW_IDX SDG_LUE9015 SDG_A2G14  \
# 0         NaN        NaN    missing       NaN    0.074385  0.226415
# 1         NaN        NaN    missing       NaN       0.128  0.284119
# 2         0.0        0.0  available   2.79174     0.48114  0.040129
# 3         0.0        0.0  available       NaN     0.44484  0.138683
# 4         0.0        0.0  available   4.25502     0.55676  0.061348
#
#   SDG_OS15MX                                           geometry
# 0      56.41  MULTIPOLYGON (((-158.01244 21.42219, -157.9915...
# 1        NaN  MULTIPOLYGON (((-149.56967 -17.51763, -149.508...
# 2      23.64  MULTIPOLYGON (((-120.46375 34.98933, -120.4411...
# 3      42.17  MULTIPOLYGON (((-121.95221 36.63574, -121.9179...
# 4      36.50  MULTIPOLYGON (((-119.82444 34.45783, -119.8131...
#
# [5 rows x 161 columns]

# %% [markdown]
# The file V1_2.gpkg contains columns that are almost identical to those in the greenspace CSV file, with the addition of a geometry column containing MULTIPOLYGON data.
#
# However, this file takes a long time to be loaded due to its size, it is better to output it as a smaller, more readable geojson file. Additionally, we should only retain the data we are interested in -- data about the United States.
#
# Hence, in the following code, I will filter out data that is not related to the United States and output the result as a geojson file named `Greenspace_US.geojson`.

# %%
gdf.head()
# Out:
#    ID_HDC_G0  QA2_1V   AREA  BBX_LATMN   BBX_LONMN  BBX_LATMX   BBX_LONMX  \
# 0        1.0     1.0  185.0  21.247683 -158.043016  21.422193 -157.730529
# 1        2.0     2.0   42.0 -17.641184 -149.628088 -17.517631 -149.508018
# 2        3.0     1.0   55.0  34.858517 -120.475511  34.989334 -120.389183
# 3        4.0     1.0   48.0  36.582997 -121.952215  36.635743 -121.811816
# 4        5.0     1.0   60.0  34.388220 -119.853855  34.457831 -119.658413
#
#    GCPNT_LAT   GCPNT_LON         CTR_MN_NM  ...      EX_SS_P00      EX_SS_P15  \
# 0  21.340678 -157.893497     United States  ...  397443.031445  444041.529529
# 1 -17.534103 -149.568053  French Polynesia  ...       0.000000       0.000000
# 2  34.923123 -120.434372     United States  ...       0.000000       0.000000
# 3  36.607720 -121.882378     United States  ...       0.000000       0.000000
# 4  34.427664 -119.743693     United States  ...       0.000000       0.000000
#
#    EX_EQ19PGA EX_EQ19MMI  EX_EQ19_Q EX_HW_IDX SDG_LUE9015 SDG_A2G14  \
# 0         NaN        NaN    missing       NaN    0.074385  0.226415
# 1         NaN        NaN    missing       NaN       0.128  0.284119
# 2         0.0        0.0  available   2.79174     0.48114  0.040129
# 3         0.0        0.0  available       NaN     0.44484  0.138683
# 4         0.0        0.0  available   4.25502     0.55676  0.061348
#
#   SDG_OS15MX                                           geometry
# 0      56.41  MULTIPOLYGON (((-158.01244 21.42219, -157.9915...
# 1        NaN  MULTIPOLYGON (((-149.56967 -17.51763, -149.508...
# 2      23.64  MULTIPOLYGON (((-120.46375 34.98933, -120.4411...
# 3      42.17  MULTIPOLYGON (((-121.95221 36.63574, -121.9179...
# 4      36.50  MULTIPOLYGON (((-119.82444 34.45783, -119.8131...
#
# [5 rows x 161 columns]

# %%
# original has O'Fallon
gdf[gdf['UC_NM_MN'].str.contains("Fallon")]
# Out:
#      ID_HDC_G0  QA2_1V   AREA  BBX_LATMN  BBX_LONMN  BBX_LATMX  BBX_LONMX  \
# 482      483.0     1.0  168.0  38.721506 -90.767949  38.837051 -90.469673
#
#      GCPNT_LAT  GCPNT_LON      CTR_MN_NM  ... EX_SS_P00  EX_SS_P15  \
# 482  38.777312 -90.611861  United States  ...       0.0        0.0
#
#      EX_EQ19PGA EX_EQ19MMI  EX_EQ19_Q EX_HW_IDX SDG_LUE9015 SDG_A2G14  \
# 482    0.048507        4.0  available   17.7047      1.5328  0.790093
#
#     SDG_OS15MX                                           geometry
# 482       75.6  MULTIPOLYGON (((-90.71472 38.83705, -90.69142 ...
#
# [1 rows x 161 columns]

# %%
# helping functions for Greenspace_Data_Cleaning below

stateboundaries = gpd.read_file('cb_2018_us_state_500k/cb_2018_us_state_500k.shp')

def statefinder(row):
    point = Point(row['Longitude'], row['Latitude'])
    state = stateboundaries[stateboundaries.contains(point)]
    
    if not state.empty:
        return state.iloc[0]['STUSPS'] 
    else:
        return np.nan

# %%
# import code from Greenspace_Data_Cleaning.ipynb to generate UC_Grouping coloumn
# which is the index after cleaned the whole dataset and exploded the Cities in Urban Center column

def Greenspace_Data_Cleaning(rawdf):

    cols_to_keep = ['GCPNT_LAT', 'GCPNT_LON', 'CTR_MN_NM', 'UC_NM_MN', 'UC_NM_LST', 'E_GR_AV14', 'E_GR_AT14', 'SDG_A2G14', 'SDG_OS15MX', 'P15', 'B15', 'BUCAP15', 'INCM_CMI', 'DEV_CMI', 'GDP15_SM', 'E_BM_NM_LST', 'E_WR_T_14','geometry'] # add 'geometry' to keep the geometry column

    df = rawdf[cols_to_keep]
    df = df[df['CTR_MN_NM'] == 'United States']
    df.replace(to_replace=['?', '??', '???', 'NAN'], value = [np.nan, np.nan, np.nan, np.nan], inplace=True)
    df.rename(columns={'GCPNT_LAT': 'Latitude', 'GCPNT_LON': 'Longitude', 'CTR_MN_NM': 'Country', 'UC_NM_MN': 'Urban Center', 'UC_NM_LST': 'Cities in Urban Center'}, inplace=True)

    a1 = df.loc[482]['Cities in Urban Center']
    a1replace = a1.replace('’', "'")

    df.at[482, 'Urban Center'] = "O'Fallon"
    df.at[482, 'Cities in Urban Center'] = a1replace

    df['Cities in Urban Center_copy'] = df['Cities in Urban Center']
    df['Cities in Urban Center'] = df['Cities in Urban Center'].str.split(';')
    df = df.explode('Cities in Urban Center')
    df.reset_index(inplace=True, drop=False)
    df.rename(columns={'index': 'UC_Grouping'}, inplace=True) # update UC Grouping to UC_Grouping
    df['Cities in Urban Center'] = df['Cities in Urban Center'].str.strip()

    mhdf = pd.read_csv('MHDS/Original/500_Cities__City-level_Data__GIS_Friendly_Format___2017_release_20240514.csv')
    mh_cities = (mhdf['PlaceName'].unique()).tolist()

    ucgroup = df[df['Cities in Urban Center'].isin(mh_cities)]
    ucgrouplist = ucgroup.index.tolist()

    df = df[df.index.isin(ucgrouplist)]

    df['State'] = df.apply(statefinder, axis=1)

    return df

# %%
green_us = Greenspace_Data_Cleaning(gdf)
print(green_us.shape)
green_us.head(3)
# Out:
# (354, 21)
#    UC_Grouping   Latitude   Longitude        Country   Urban Center  \
# 0            0  21.340678 -157.893497  United States       Honolulu
# 4            2  34.923123 -120.434372  United States    Santa Maria
# 6            4  34.427664 -119.743693  United States  Santa Barbara
#
#   Cities in Urban Center  E_GR_AV14   E_GR_AT14  SDG_A2G14  SDG_OS15MX  ...  \
# 0               Honolulu   0.369290  183.811667   0.226415       56.41  ...
# 4            Santa Maria   0.312846   54.450694   0.040129       23.64  ...
# 6          Santa Barbara   0.362785   59.576284   0.061348       36.50  ...
#
#          B15     BUCAP15  INCM_CMI DEV_CMI      GDP15_SM  \
# 0  80.647377  157.252219       HIC     MDR  2.192668e+10
# 4  42.000805  340.967420       HIC     MDR  4.174295e+09
# 6  38.101749  332.032274       HIC     MDR  4.159702e+09
#
#                                       E_BM_NM_LST  E_WR_T_14  \
# 0  Tropical and Subtropical Dry Broadleaf Forests  23.526622
# 4     Mediterranean Forests, Woodlands, and Scrub  14.718191
# 6     Mediterranean Forests, Woodlands, and Scrub  15.376907
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-158.01244 21.42219, -157.9915...
# 4  MULTIPOLYGON (((-120.46375 34.98933, -120.4411...
# 6  MULTIPOLYGON (((-119.82444 34.45783, -119.8131...
#
#            Cities in Urban Center_copy State
# 0  Honolulu; Waipahu; Pearl City; Aiea    HI
# 4                          Santa Maria    CA
# 6                        Santa Barbara    CA
#
# [3 rows x 21 columns]

# %% [markdown]
# After cleaned the geometry file and generate a dataframe `green_us` based on Greenspace_Data_Cleaning.ipynb, we need to conduct a further cleaning to make sure the geometry data align with the merged dataset.
#
# So we will load the merged dataset and manipulated `green_us` for further cleaning.

# %%
file_path = 'uc_group_merged_greenspace_mh.csv'

# %%
# load merged dataset and manipulate rows to match the merged dataset
def rows_matching_with_merged(path, df = green_us, key_col = 'UC_Grouping'):
    mer_df = pd.read_csv(path,index_col = 0)

    key_list = (mer_df[key_col].unique()).tolist()

    matchgroup = df[df[key_col].isin(key_list)]
    matchgrouplist = matchgroup.index.tolist()

    df = df[df.index.isin(matchgrouplist)]

    return mer_df, df

# %%
uc_merged, up_greenus = rows_matching_with_merged(file_path, df = green_us, key_col = 'UC_Grouping')

# presenting merged dataframe
print(uc_merged.shape)
uc_merged.head(3)
# Out:
# (329, 19)
#    Population2010  MHLTH_AdjPrev  UC_Grouping   Latitude  Longitude  \
# 0          212237           15.6          485  33.509025 -86.823651
# 1          180105           13.4          501  34.726065 -86.609995
# 2          195111           15.0          422  30.692377 -88.093685
#
#    E_GR_AV14   E_GR_AT14  SDG_A2G14  SDG_OS15MX           P15         B15  \
# 0   0.494568  219.996230   0.773812       74.85  196387.76700  152.894608
# 1   0.521522   88.700999   0.802599       66.37   86467.06209   59.674004
# 2   0.467515  122.669298   0.822213       63.32  118578.67890   71.298004
#
#       BUCAP15      GDP15_SM  E_WR_T_14 State INCM_CMI DEV_CMI  \
# 0  778.534274  6.184143e+09  17.497644    AL      HIC     MDR
# 1  690.135667  2.498489e+09  16.321889    AL      HIC     MDR
# 2  601.271703  4.072112e+09  20.312027    AL      HIC     MDR
#
#                              E_BM_NM_LST Cities in Urban Center_copy
# 0  Temperate Broadleaf and Mixed Forests                Birmingham;
# 1  Temperate Broadleaf and Mixed Forests                  Huntsville
# 2           Temperate Coniferous Forests                      Mobile

# %%
# presenting updated green_us dataframe
up_greenus.shape
up_greenus.head()
# Out:
#    UC_Grouping   Latitude   Longitude        Country   Urban Center  \
# 0            0  21.340678 -157.893497  United States       Honolulu
# 4            2  34.923123 -120.434372  United States    Santa Maria
# 6            4  34.427664 -119.743693  United States  Santa Barbara
# 8            6  36.688991 -121.640831  United States        Salinas
# 9            7  34.217486 -119.209132  United States         Oxnard
#
#   Cities in Urban Center  E_GR_AV14   E_GR_AT14  SDG_A2G14  SDG_OS15MX  ...  \
# 0               Honolulu   0.369290  183.811667   0.226415       56.41  ...
# 4            Santa Maria   0.312846   54.450694   0.040129       23.64  ...
# 6          Santa Barbara   0.362785   59.576284   0.061348       36.50  ...
# 8                Salinas   0.339631   53.886276   0.076114       24.61  ...
# 9                 Oxnard   0.299903  135.224578   0.036199       28.65  ...
#
#          B15     BUCAP15  INCM_CMI DEV_CMI      GDP15_SM  \
# 0  80.647377  157.252219       HIC     MDR  2.192668e+10
# 4  42.000805  340.967420       HIC     MDR  4.174295e+09
# 6  38.101749  332.032274       HIC     MDR  4.159702e+09
# 8  41.044956  274.027026       HIC     MDR  4.813837e+09
# 9  97.043526  325.861123       HIC     MDR  1.074582e+10
#
#                                       E_BM_NM_LST  E_WR_T_14  \
# 0  Tropical and Subtropical Dry Broadleaf Forests  23.526622
# 4     Mediterranean Forests, Woodlands, and Scrub  14.718191
# 6     Mediterranean Forests, Woodlands, and Scrub  15.376907
# 8     Mediterranean Forests, Woodlands, and Scrub  15.274110
# 9     Mediterranean Forests, Woodlands, and Scrub  17.053577
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-158.01244 21.42219, -157.9915...
# 4  MULTIPOLYGON (((-120.46375 34.98933, -120.4411...
# 6  MULTIPOLYGON (((-119.82444 34.45783, -119.8131...
# 8  MULTIPOLYGON (((-121.66750 36.74127, -121.6560...
# 9  MULTIPOLYGON (((-119.31772 34.29254, -119.2952...
#
#            Cities in Urban Center_copy State
# 0  Honolulu; Waipahu; Pearl City; Aiea    HI
# 4                          Santa Maria    CA
# 6                        Santa Barbara    CA
# 8                              Salinas    CA
# 9                      Oxnard; Ventura    CA
#
# [5 rows x 21 columns]

# %% [markdown]
# Seems updated green_us has more rows than merged dataset.
#
# It's acutally OK if the number of rows of green_us doesn't match of merged dataset, as long as we have holistic geometry data that can present the all cities areas of merged dataset.
#
# So we need to make sure we got enough geometry data in updated green_us by comparing the unique number of UC_Grouping of both datasets.

# %%
n_mer = len(uc_merged['UC_Grouping'].unique())
n_green = len(up_greenus['UC_Grouping'].unique())

if n_mer == n_green:
    print(f"The numbers of unique UC_Grouping are the same, which is {n_mer}.")
else:
    print(f"Numbers are not the same. Merged datasets has {n_mer} unique UC_Grouping, Green_us has {n_green} uniques UC_Grouping")
# Out:
# The numbers of unique UC_Grouping are the same, which is 228.

# %% [markdown]
# Since we have covered all cities, we can just keep 1 geometry data point for 1 unique UC_Grouping and also remove less relevant data to make the file size smaller.

# %%
def smaller_file(gdf, key_cols = ['UC_Grouping','geometry']):
    df = gdf[key_cols]
    return df.drop_duplicates()

# %%
ess_geo = smaller_file(up_greenus)
print(ess_geo.shape)
ess_geo.head()
# Out:
# (228, 2)
#    UC_Grouping                                           geometry
# 0            0  MULTIPOLYGON (((-158.01244 21.42219, -157.9915...
# 4            2  MULTIPOLYGON (((-120.46375 34.98933, -120.4411...
# 6            4  MULTIPOLYGON (((-119.82444 34.45783, -119.8131...
# 8            6  MULTIPOLYGON (((-121.66750 36.74127, -121.6560...
# 9            7  MULTIPOLYGON (((-119.31772 34.29254, -119.2952...

# %% [markdown]
# We have cleaned less relevant rows and columns, we are ready to output the geojson file.

# %%
# output cleaned geometry df to geojson
_ = gcm.bound_load_file_output_geojson(file_path=_, df=ess_geo, full_state=True, output=True, output_folder='', output_filename='Greenspace_US.geojson')
# Out:
# Be aware of large dataset!

# %% [markdown]
# # Choropleth Map for Merged Dataset
#
# Now we will create a choropleth map to visualize features geographically.

# %%
# check the geojson file
f = open('Greenspace_US.geojson', 'r')
f.readlines()[:10]
# Out:
# ['{\n',
#  '"type": "FeatureCollection",\n',
#  '"crs": { "type": "name", "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" } },\n',
#  '"features": [\n',
#  '{ "type": "Feature", "properties": { "UC_Grouping": 0 }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ -158.012436513808552, 21.422192591895211 ], [ -157.991578163004789, 21.422192591895211 ], [ -157.986010505889595, 21.413880829006239 ], [ -157.944295274387656, 21.413880829006239 ], [ -157.938731796317313, 21.405569246135077 ], [ -157.928303355789296, 21.405569246135077 ], [ -157.91163026842824, 21.380635576791448 ], [ -157.901202928870106, 21.380635576791448 ], [ -157.890101799975866, 21.3640140291173 ], [ -157.879675193504255, 21.3640140291173 ], [ -157.87412905162148, 21.355703524595818 ], [ -157.853276571229003, 21.355703524595818 ], [ -157.842193859673387, 21.339083053766089 ], [ -157.831768351492457, 21.339083053766089 ], [ -157.826231413465422, 21.330773087290719 ], [ -157.80538112858352, 21.330773087290719 ], [ -157.783263292469286, 21.297535012370442 ], [ -157.77283961120537, 21.297535012370442 ], [ -157.767317260696501, 21.289225940968262 ], [ -157.736047311450847, 21.289225940968262 ], [ -157.730528750706981, 21.28091704833033 ], [ -157.740951702451554, 21.28091704833033 ], [ -157.73543547166642, 21.272608334373245 ], [ -157.745858058918429, 21.272608334373245 ], [ -157.777125820674371, 21.272608334373245 ], [ -157.771610826493259, 21.264299799013603 ], [ -157.782033049430652, 21.264299799013603 ], [ -157.776520384920502, 21.255991442168042 ], [ -157.786942243721285, 21.255991442168042 ], [ -157.781431908471717, 21.247683263753188 ], [ -157.791853403313752, 21.247683263753188 ], [ -157.802877495305466, 21.264299799013603 ], [ -157.813299718242916, 21.264299799013603 ], [ -157.81881616968235, 21.272608334373245 ], [ -157.829238756934359, 21.272608334373245 ], [ -157.834758268152797, 21.28091704833033 ], [ -157.845181219897341, 21.28091704833033 ], [ -157.850703792018209, 21.289225940968262 ], [ -157.861127108433408, 21.289225940968262 ], [ -157.866652742580953, 21.297535012370442 ], [ -157.877076423844898, 21.297535012370442 ], [ -157.882605121143911, 21.305844262620319 ], [ -157.893029167434776, 21.305844262620319 ], [ -157.89856092901087, 21.314153691801348 ], [ -157.919409752002707, 21.314153691801348 ], [ -157.924944944365421, 21.322463299996983 ], [ -157.935369721244683, 21.322463299996983 ], [ -157.940907980315814, 21
zoom_start=3
legend='Average Mental Health Prevalence (%)'

boundary_file = 'Greenspace_US.geojson'
df = uc_merged

m = folium.Map(location=[lat, lon], zoom_start=zoom_start)

geodata = json.load(open(boundary_file, 'r'))

cp = folium.Choropleth(
    geo_data=geodata,
    data=df,
    columns=geo_col,
    key_on=key,
    fill_color=color,
    fill_opacity=opacity,
    line_weight=weight,
    legend_name=legend
).add_to(m)


display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ee85e1dc1fcb90536cad406d0270dd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ee85e1dc1fcb90536cad406d0270dd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ee85e1dc1fcb90536cad406d0270dd9 = L.map(
#                 &quot;map_6ee85e1dc1fcb90536cad406d0270dd9&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6023cb536496be4eb9424eafdf39146e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_6023cb536496be4eb9424eafdf39146e.addTo(map_6ee85e1dc1fcb90536cad406d0270dd9);
#
#             var choropleth_a1ce81b66677b47dc91d56afe56e388b = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_802588a37ed5fc64bf7d778717ad8a2e_styler(feature) {
#             switch(feature.properties.UC_Grouping) {
#                 case 0: case 9: case 13: case 276: case 314: case 322: case 448: case 509: case 563: case 633: case 767: case 854:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case 2: case 38: case 40: case 49: case 53: case 68: case 161: case 365: case 378: case 394: case 400: case 412: case 422: case 442: case 470: case 481: case 485: case 533: case 555: case 593: case 639: case 683: case 692: case 753: case 786: case 792: case 845: case 889: case 909: case 932: case 949: case 980: case 981: case 996:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case 4: case 11: case 15: case 21: case 23: case 36: case 78: case 170: case 182: case 192: case 195: case 234: case 264: case 271: case 272: case 283: case 291: case 294: case 311: case 317: case 355: case 382: case 407: case 408: case 416: case 516: case 517: case 553: case 558: case 575: case 576: case 587: case 636: case 667: case 693: case 762: case 774: case 846: case 969:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case 6: case 7: case 20: case 28: case 31: case 32: case 33: case 34: case 35: case 44: case 45: case 47: case 48: case 55: case 57: case 59: case 66: case 73: case 81: case 83: case 89: case 139: case 165: case 181: case 205: case 240: case 245: case 308: case 327: case 348: case 384: case 385: case 396: case 399: case 410: case 486: case 492: case 500: case 501: case 506: case 508: case 529: case 534: case 544: case 567: case 582: case 590: case 594: case 604: case 623: case 627: case 649: case 650: case 655: case 661: case 674: case 680: case 685: case 708: case 717: case 724: case 728: case 732: case 748: case 761: case 769: case 801: case 879: case 897: case 912: case 928: case 971: case 982: case 1010: case 1021: case 1024: case 1027:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case 16: case 17: case 24: case 25: case 26: case 27: case 29: case 97: case 100: case 146: case 189: case 191: case 232: case 238: case 246: case 247: case 249: case 252: case 256: case 259: case 263: case 288: case 298: case 313: case 332: case 336: case 341: case 346: case 363: case 404: case 406: case 431: case 473: case 482: case 512: case 524: case 549: case 626: case 634: case 647: case 664: case 673: case 676: case 697: case 706: case 710: case 741: case 751: case 771: case 789: case 818: case 827: case 849: case 944: case 1008: case 1023: case 1044:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_802588a37ed5fc64bf7d778717ad8a2e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_802588a37ed5fc64bf7d778717ad8a2e = L.geoJson(null, {
#                 onEachFeature: geo_json_
